# %%
import sys
import os

root_path = os.path.abspath("..")   # go up one directory
sys.path.append(root_path)

from Project.param import *
from Project.sentiment_analysis import *

# %%
df_aapl_news = get_filtered_massive_sentiment_simple()
df_aapl_news
# Out:
#            ticker sentiment
# date
# 2025-01-01   AAPL   neutral
# 2025-01-01   AAPL   neutral
# 2025-01-03   AAPL  negative
# 2025-01-03   AAPL  positive
# 2025-01-03   AAPL   neutral
# 2025-01-03   AAPL  positive
# 2025-01-03   AAPL  negative
# 2025-01-04   AAPL   neutral
# 2025-01-05   AAPL  positive
# 2025-01-05   AAPL   neutral
# 2025-01-05   AAPL   neutral
# 2025-01-05   AAPL  positive
# 2025-01-06   AAPL  positive
# 2025-01-06   AAPL  positive
# 2025-01-06   AAPL  positive
# 2025-01-06   AAPL   neutral
# 2025-01-07   AAPL  positive
# 2025-01-07   AAPL  positive
# 2025-01-08   AAPL   neutral
# 2025-01-08   AAPL  negative

# %%
df_final = get_daily_sentiment_filled(df_aapl_news)
df_final
# Out:
#             sentiment
# date
# 2025-01-01       0.00
# 2025-01-02       0.00
# 2025-01-03       0.00
# 2025-01-04       0.00
# 2025-01-05       0.50
# 2025-01-06       0.75
# 2025-01-07       1.00
# 2025-01-08      -0.50
# 2025-01-09       0.00
# 2025-01-10       0.00
# 2025-01-11       0.00
# 2025-01-12       0.00
# 2025-01-13       0.00
# 2025-01-14       0.00
# 2025-01-15       0.00
# 2025-01-16       0.00
# 2025-01-17       0.00
# 2025-01-18       0.00
# 2025-01-19       0.00
# 2025-01-20       0.00
