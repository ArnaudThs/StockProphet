# %%
import pandas as pd
import os, sys
project_root = os.path.abspath("../")
sys.path.append(project_root)
print("Added path:", project_root)
# Out:
# Added path: /Users/hippolyteheger/code/ArnaudThs/StockProphet/StockProphet

# %%
from Project.param import *
from Project.data import *
from Project.sentiment_analysis import *
from Project.model import *

# %%
from Project.main import *
print("main.py imports successfully!")
# Out:
# main.py imports successfully!
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
pip install gymnasium stable-baselines3 pandas numpy tensorflow shimmy
# Out:
# Requirement already satisfied: gymnasium in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: stable-baselines3 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: pandas in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: tensorflow in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: shimmy in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from stable-baselines3) (2.9.1)
# Requirement already satisfied: matplotlib in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from stable-baselines3) (3.10.7)
# Requirement already satisfied: filelock in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
main()
# Out:
# /Users/hippolyteheger/code/ArnaudThs/StockProphet/StockProphet/Project/data.py:17: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# --- Starting Trading Bot Pipeline ---
# Loading data for AAPL...
# [*********************100%***********************]  1 of 1 completed
# Running RNN Analysis...
# Loading existing LSTM predictor...
# Generating predictions...
# Merging Data...
# Train Size: 1063, Test Size: 266
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2413 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1880        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012742728 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000627   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 4.78        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1784        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014148541 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0025397153 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.999        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000151    |
# |    value_loss           | 2.19         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1717        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.003204179 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000416   |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1702        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012017429 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010073759 |
# |    clip_fraction        | 0.00562     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.247       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1669         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0076268516 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.785        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 2.05         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1653         |
# |    iterations           | 9            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0096167745 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000628     |
# |    value_loss           | 2.83         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1650       |
# |    iterations           | 10         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01461515 |
# |    clip_fraction        | 0.0377     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.67       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00322   |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1649        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008672669 |
# |    clip_fraction        | 0.00747     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.46        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 3.17e-05    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1646        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006534836 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 4.38        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1645         |
# |    iterations           | 13           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0012891489 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000201     |
# |    value_loss           | 0.384        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 14          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013656402 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.073       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000802   |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011265892 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 0.454       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1636         |
# |    iterations           | 16           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0113301035 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.863        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 2            |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1633       |
# |    iterations           | 17         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01450607 |
# |    clip_fraction        | 0.0391     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.211      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00279   |
# |    value_loss           | 0.593      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1632        |
# |    iterations           | 18          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005771177 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000791   |
# |    value_loss           | 9.12        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1632         |
# |    iterations           | 19           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0043317676 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.549        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000543     |
# |    value_loss           | 2.57         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 20          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003897112 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.235       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000221   |
# |    value_loss           | 0.741       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1617       |
# |    iterations           | 21         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01432783 |
# |    clip_fraction        | 0.065      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0384    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00486   |
# |    value_loss           | 0.179      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1618        |
# |    iterations           | 22          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012255762 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1619        |
# |    iterations           | 23          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011272302 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0433      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1619        |
# |    iterations           | 24          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008859092 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.539       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 1.82        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1618        |
# |    iterations           | 25          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009986753 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.41        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000832   |
# |    value_loss           | 11          |
# -----------------------------------------
# Testing Strategy...
# Running Backtest...
#
# ========================================
#       PERFORMANCE REPORT
# ========================================
# Metric               | AI Strategy  | Buy & Hold
# --------------------------------------------------
# Total Return         |    -8.90%    |     3.14%
# Max Drawdown         |   -33.13%    |   -33.36%
# Sharpe Ratio         |    -0.17      |    -0.19
# ========================================
# Done.

# %%
df_ohlcv = load_market_data(TICKER)
df_local = df_ohlcv.rename(columns={"date": "Date"})[["Date", "close"]].copy()
df_ohlcv.head()
# Out:
# /Users/hippolyteheger/code/ArnaudThs/StockProphet/StockProphet/Project/data.py:17: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
#         date      close       high        low       open     volume
# 0 2020-01-02  72.468269  72.528589  71.223267  71.476607  135480400
# 1 2020-01-03  71.763695  72.523723  71.539307  71.696137  146322800
# 2 2020-01-06  72.335579  72.374185  70.634562  70.885494  118387200
# 3 2020-01-07  71.995361  72.600968  71.775796  72.345212  108872000
# 4 2020-01-08  73.153503  73.455103  71.698589  71.698589  132079200

# %%
df = load_data(ticker = TICKER, start_date = START_DATE, end_date = END_DATE)
df
# Out:
# /Users/hippolyteheger/code/ArnaudThs/StockProphet/StockProphet/Project/data.py:17: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
#            Date       Close        High         Low        Open     Volume
# 0    2020-01-02   72.468269   72.528589   71.223267   71.476607  135480400
# 1    2020-01-03   71.763695   72.523723   71.539307   71.696137  146322800
# 2    2020-01-06   72.335579   72.374185   70.634562   70.885494  118387200
# 3    2020-01-07   71.995361   72.600968   71.775796   72.345212  108872000
# 4    2020-01-08   73.153503   73.455103   71.698589   71.698589  132079200
# ...         ...         ...         ...         ...         ...        ...
# 1374 2025-06-23  201.076660  201.874982  198.542003  201.206392   55814300
# 1375 2025-06-24  199.879181  203.012583  199.779385  202.164363   54064000
# 1376 2025-06-25  201.136536  203.242103  200.198508  201.026766   39525700
# 1377 2025-06-26  200.577698  202.214251  199.040940  201.006787   50799100
# 1378 2025-06-27  200.657532  202.793035  199.579799  201.465827   73188600
#
# [1379 rows x 6 columns]

# %%
WINDOW_SIZE = 50
TRAIN_RATIO = 0.8
BATCH_SIZE = 32
LSTM_EPOCHS = 10
RNN_MODEL_SAVE = "lstm_rnn.keras"

# %%
# -------------------------
# Utility: Build RNN predictions aligned to dates
# -------------------------
def build_rnn_predictions(df_ohlc: pd.DataFrame, window_size: int = WINDOW_SIZE,
                          epochs: int = LSTM_EPOCHS, batch_size: int = BATCH_SIZE,
                          force_retrain: bool = True) -> pd.Series:
    """
    Train LSTM on historical Close and produce a one-day-ahead prediction for each day
    where enough history exists. Returns a pd.Series indexed by date with predicted value
    in the same scale as the original Close (not scaled).
    """
    df_local = df_ohlc.copy()

    # Normalize date column name
    if "date" in df_local.columns:
        df_local = df_local.rename(columns={"date": "Date"})
    elif "Date" not in df_local.columns:
        raise ValueError("DataFrame must contain either 'Date' or 'date' column.")

    df_local = df_local[["Date", "Close"]].reset_index(drop=True)
    # Use the helper which returns X_train,y_train,X_test,y_test,scaler
    X_train, y_train, X_test, y_test, scaler = train_test_split_lstm(df_local)

    # Build model
    input_shape = (X_train.shape[1], X_train.shape[2])  # (seq_len, n_features)
    model = LSTM_model(input_shape)
    model = compile_LSTM(model)

    # Train model (if force_retrain or no saved model)
    if force_retrain or not os.path.exists(RNN_MODEL_SAVE):
        print("Training LSTM predictor...")
        train_LSTM(model, X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
        model.save(RNN_MODEL_SAVE)
    else:
        print("Loading existing LSTM predictor...")
        from keras.models import load_model
        model = load_model(RNN_MODEL_SAVE)

    # Now generate sliding-window predictions across the full dataset
    closes = df_local["Close"].values.reshape(-1, 1)
    closes_scaled = scaler.transform(closes)  # use same scaler

    preds = []
    dates = []
    for end_idx in range(window_size, len(closes_scaled)):
        start_idx = end_idx - window_size
        seq = closes_scaled[start_idx:end_idx]  # shape (window_size, 1)
        seq = seq.reshape((1, seq.shape[0], seq.shape[1]))
        pred_scaled = model.predict(seq, verbose=0)
        pred = scaler.inverse_transform(pred_scaled.reshape(-1, 1))[0, 0]
        preds.append(pred)
        dates.append(df_local.loc[end_idx, "Date"])  # prediction aligned to day end_idx

    preds_series = pd.Series(data=preds, index=pd.to_datetime(dates))
    preds_series.name = "rnn_pred_close"
    return preds_series


# -------------------------
# Utility: Merge OHLC / Sentiment / RNN preds and create lag-features
# -------------------------
def build_merged_dataframe(df_ohlc: pd.DataFrame, df_sentiment: pd.DataFrame,
                           rnn_preds: pd.Series, window_size: int = WINDOW_SIZE) -> pd.DataFrame:
    """
    Returns DataFrame with columns:
    Date, Open, High, Low, Close, Volume, sentiment, rnn_pred_close,
    close_lag_1 .. close_lag_{window_size}, next_return (reward target).
    """
    # Normalize column names & Date
    df = df_ohlc.copy()
    df["date"] = pd.to_datetime(df["date"])
    df = df.set_index("date").sort_index()

    # Merge sentiment (df_sentiment is indexed by date)
    df_sent = df_sentiment.copy()
    if "date" in df_sent.columns or df_sent.index.name == "date":
        df_sent.index = pd.to_datetime(df_sent.index)
    df_sent = df_sent.rename(columns={df_sent.columns[0]: "sentiment"})
    df = df.join(df_sent, how="left")
    df["sentiment"] = df["sentiment"].fillna(0.0)

    # Merge RNN preds (already indexed by date)
    df = df.join(rnn_preds.rename("rnn_pred_close"), how="left")

    # compute returns (next day) for reward and intraday if needed
    df["close"] = df["Close"].astype(float)
    df["return"] = df["close"].pct_change()
    # next day return as target (reward reference)
    df["next_return"] = df["return"].shift(-1)

    # Create lag features for close (flattened)
    for i in range(1, window_size + 1):
        df[f"close_lag_{i}"] = df["close"].shift(i)

    # drop rows without enough history or without next_return
    df = df.dropna().reset_index()
    return df

# %%
series = build_rnn_predictions(df_ohlc=df_ohlcv)
# Out:
# Training LSTM predictor...
# Epoch 1/20
# /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0022 - loss: 0.0374
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0033
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0019
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0017
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0018
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0016
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0022 - loss: 0.0015
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0016
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0016
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0022 - loss: 0.0015
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0014
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0014
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0022 - loss: 0.0014
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0022 - loss: 0.0012

# %%
series
# Out:
# 2020-03-16     70.116516
# 2020-03-17     69.230682
# 2020-03-18     68.324776
# 2020-03-19     67.381516
# 2020-03-20     66.440697
#                  ...
# 2025-06-23    194.981354
# 2025-06-24    194.927063
# 2025-06-25    194.953796
# 2025-06-26    195.107971
# 2025-06-27    195.303665
# Name: rnn_pred_close, Length: 1329, dtype: float32

# %%
df_daily = fetch_daily_ticker_sentiment(api_key = API_KEY_MASSIVE, ticker = SENTIMENT_TICKERS, start_date = SENTIMENT_START_DATE, end_date = SENTIMENT_END_DATE)

# %%
df = build_merged_dataframe(df_ohlc = df_ohlcv, df_sentiment=df_daily,
                           rnn_preds = series, window_size = 50)

# %%
df
# Out:
#            date       Close        High         Low        Open     Volume  \
# 0    2020-03-16   58.578979   62.659018   58.044485   58.516096  322423600
# 1    2020-03-17   61.154697   62.303491   57.657516   59.860788  324056000
# 2    2020-03-18   59.657642   60.463010   57.347955   57.988865  300233600
# 3    2020-03-19   59.200535   61.149861   58.675716   59.831769  271857200
# 4    2020-03-20   55.442165   60.905602   55.142268   59.780988  401693200
# ...         ...         ...         ...         ...         ...        ...
# 1323 2025-06-20  200.577713  201.276239  196.446411  197.823517   96813500
# 1324 2025-06-23  201.076645  201.874967  198.541988  201.206377   55814300
# 1325 2025-06-24  199.879181  203.012583  199.779385  202.164363   54064000
# 1326 2025-06-25  201.136520  203.242088  200.198493  201.026751   39525700
# 1327 2025-06-26  200.577713  202.214267  199.040955  201.006802   50799100
#
#       sentiment  rnn_pred_close       close    return  ...  close_lag_41  \
# 0           0.0       70.116516   58.578979 -0.128647  ...     75.119934
# 1           0.0       69.230682   61.154697  0.043970  ...     76.060921
# 2           0.0       68.324776   59.657642 -0.024480  ...     76.902977
# 3           0.0       67.381516   59.200535 -0.007662  ...     76.381805
# 4           0.0       66.440697   55.442165 -0.063485  ...     76.654480
# ...         ...             ...         ...       ...  ...           ...
# 1323        1.0      195.242447  200.577713  0.022485  ...    199.059326
# 1324        2.0      194.981354  201.076645  0.002487  ...    203.902740
# 1325        0.0      194.927063  199.879181 -0.005955  ...    207.659912
# 1326       -1.0      194.953796  201.136520  0.006290  ...    208.566803
# 1327       -1.0      195.107971  200.577713 -0.002778  ...    209.423874
#
#       close_lag_42  close_lag_43  close_lag_44  close_lag_45  close_lag_46  \
# 0        75.443237     76.475914     74.876221     74.707329     73.153473
# 1        75.119934     75.443237     76.475914     74.876221     74.707329
# 2        76.060921     75.119934     75.443237     76.475914     74.876221
# 3        76.902977     76.060921     75.119934     75.443237     76.475914
# 4        76.381805     76.902977     76.060921     75.119934     75.443237
# ...            ...           ...           ...           ...           ...
# 1323    192.501724    196.308716    193.607956    201.451126    201.829849
# 1324    199.059326    192.501724    196.308716    193.607956    201.451126
# 1325    203.902740    199.059326    192.501724    196.308716    193.607956
# 1326    207.659912    203.902740    199.059326    192.501724    196.308716
# 1327    208.566803    207.659912    203.902740    199.059326    192.501724
#
#       close_lag_47  close_lag_48  close_lag_49  close_lag_50
# 0        71.995354     72.335533     71.763725     72.468262
# 1        73.153473     71.995354     72.335533     71.763725
# 2        74.707329     73.153473     71.995354     72.335533
# 3        74.876221     74.707329     73.153473     71.995354
# 4        76.475914     74.876221     74.707329     73.153473
# ...            ...           ...           ...           ...
# 1323    197.474731    189.771072    198.172348    171.832428
# 1324    201.829849    197.474731    189.771072    198.172348
# 1325    201.451126    201.829849    197.474731    189.771072
# 1326    193.607956    201.451126    201.829849    197.474731
# 1327    196.308716    193.607956    201.451126    201.829849
#
# [1328 rows x 61 columns]

# %%
from Project.main import main

main()  # will execute the full pipeline
# Out:
# /Users/hippolyteheger/code/ArnaudThs/StockProphet/StockProphet/Project/data.py:17: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Loading OHLC data...
# Computing RNN predictions...
# Training LSTM predictor...
# Epoch 1/20
# /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0022 - loss: 0.0521
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0022 - loss: 0.0040
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0022 - loss: 0.0021
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0017
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0016
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0017
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0016
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0015
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0015
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0014
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0015
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0014
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0022 - loss: 0.0013
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0012
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0011
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0022 - loss: 0.0012
# Fetching sentiment...
# Sentiment fetch failed, filling zeros: HTTPSConnectionPool(host='api.massive.com', port=443): Max retries exceeded with url: /v2/reference/news?cursor= (Caused by ResponseError('too many 429 error responses'))
# Merging datasets...
# Merged dataset shape: (1328, 60)
# Saving merged dataset to merged_dataset.csv...

# %%
# main.py
import os
import numpy as np
import pandas as pd
from datetime import datetime
from typing import Tuple

# your modules
from Project.data import load_data, train_test_split_lstm
from Project.model import LSTM_model, compile_LSTM, train_LSTM, test_lstm_model
from Project.sentiment_analysis import fetch_daily_ticker_sentiment
from Project.param import *

# RL imports
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

WINDOW_SIZE = 50
TRAIN_RATIO = 0.8
BATCH_SIZE = 32
LSTM_EPOCHS = 10
PPO_TIMESTEPS = 50_000  # reduce for quick tests
MODEL_SAVE_PATH = "ppo_trader.zip"
RNN_MODEL_SAVE = "lstm_rnn.keras"
TRANSACTION_COST_PCT = 0.0005



import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd



class TradingEnv(gym.Env):
    metadata = {"render_modes": ["human"]}

    def __init__(self, df: pd.DataFrame, window_size: int = 30):
        super().__init__()
        self.df = df.reset_index(drop=True)
        self.window_size = window_size
        self.initial_cash = 10_000
        self.cash = self.initial_cash
        self.shares = 0
        self.current_step = window_size

        self.feature_columns = [
            "close",
            "sentiment",
            "rnn_pred_close",
        ] + [c for c in df.columns if c.startswith("close_lag_")]

        self.num_features = len(self.feature_columns)
        obs_size = self.window_size * self.num_features + 2

        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(obs_size,), dtype=np.float32)
        self.action_space = spaces.Discrete(3)

        # track history for plotting
        self.portfolio_history = []
        self.action_history = []
        self.reward_history = []

    def _get_observation(self):
        start = self.current_step - self.window_size
        end = self.current_step
        window = self.df.loc[start:end - 1, self.feature_columns].values
        obs = np.concatenate([window.flatten(), np.array([self.cash, self.shares], dtype=np.float32)])
        return obs.astype(np.float32)

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.cash = self.initial_cash
        self.shares = 0
        self.current_step = self.window_size
        self.portfolio_history = []
        self.action_history = []
        self.reward_history = []
        return self._get_observation(), {}

    def step(self, action):
        price = self.df.loc[self.current_step, "close"]

        # BUY
        if action == 1 and self.cash >= price:
            cost = price * (1 + TRANSACTION_COST_PCT)
            if self.cash >= cost:
                self.cash -= cost
                self.shares += 1

        # SELL
        elif action == 2 and self.shares > 0:
            proceeds = price * (1 - TRANSACTION_COST_PCT)
            self.cash += proceeds
            self.shares -= 1

        self.current_step += 1
        terminated = self.current_step >= len(self.df) - 1
        truncated = False

        # reward = portfolio value
        portfolio_value = self.cash + self.shares * self.df.loc[self.current_step, "close"]
        reward = portfolio_value - (self.portfolio_history[-1] if self.portfolio_history else self.initial_cash)

        # store for plotting
        self.portfolio_history.append(portfolio_value)
        self.action_history.append(action)
        self.reward_history.append(reward)

        return self._get_observation(), reward, terminated, truncated, {}

    def render(self):
        print(f"Step {self.current_step} | Cash: {self.cash:.2f} | Shares: {self.shares} | Portfolio: {self.cash + self.shares * self.df.loc[self.current_step, 'close']:.2f}")

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv


def train_ppo_on_df(df, timesteps=5000):
    env = DummyVecEnv([lambda: TradingEnv(df, window_size=30)])
    model = PPO("MlpPolicy", env, verbose=1)
    model.learn(total_timesteps=timesteps)
    model.save("ppo_trading_model")
    return model

# %%
def test_and_plot(df, model_path="ppo_trading_model.zip"):
    from matplotlib import pyplot as plt

    model = PPO.load(model_path)
    env = TradingEnv(df)
    obs, _ = env.reset()
    done = False

    while not done:
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            done = True

    # Plot portfolio
    plt.figure(figsize=(14,5))
    plt.plot(env.portfolio_history, label="Portfolio Value")
    plt.title("Portfolio Value Over Time")
    plt.xlabel("Step")
    plt.ylabel("Portfolio Value")
    plt.grid(True)
    plt.legend()
    plt.show()

    # Plot rewards
    plt.figure(figsize=(14,5))
    plt.plot(env.reward_history, label="Reward per step")
    plt.title("Reward Over Time")
    plt.xlabel("Step")
    plt.ylabel("Reward")
    plt.grid(True)
    plt.legend()
    plt.show()

    # Plot actions overlay on price
    plt.figure(figsize=(14,5))
    plt.plot(df["close"].values[env.window_size:], label="Price")
    actions = np.array(env.action_history)
    buys = np.where(actions==1)[0]
    sells = np.where(actions==2)[0]
    plt.scatter(buys, df["close"].values[env.window_size:][buys], marker="^", color="g", label="Buy")
    plt.scatter(sells, df["close"].values[env.window_size:][sells], marker="v", color="r", label="Sell")
    plt.title("Price with Buy/Sell Actions")
    plt.xlabel("Step")
    plt.ylabel("Price")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
pip install "shimmy>=2.0"
# Out:
# Requirement already satisfied: shimmy>=2.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from shimmy>=2.0) (2.2.6)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from shimmy>=2.0) (1.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/hippolyteheger/.pyenv/versions/3.10.6/envs/StockProphet/lib/python3.10/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
train_size = int(len(df) * 0.8)
df_train = df.iloc[:train_size].reset_index(drop=True)
df_test  = df.iloc[train_size:].reset_index(drop=True)
model = train_ppo_on_df(df_train)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2192 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1494        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010811789 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000418   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 7.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010586365 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.000437   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.19e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00112     |
# |    value_loss           | 1.06e+05    |
# -----------------------------------------

# %%
test_and_plot(df_test)

# %%
q
